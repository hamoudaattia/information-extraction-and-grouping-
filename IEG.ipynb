# %% [markdown]
# <a href="https://colab.research.google.com/github/hamoudaattia/information-extraction-and-grouping-/blob/main/IEG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
a = ("/content/drive/MyDrive/eurosurv-25-3-1-1.png")

# %%
# !pip install easyocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import easyocr
reader = easyocr.Reader(['en'])
result = reader.readtext(a)
# Out:
# WARNING:easyocr.easyocr:CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
import matplotlib.pyplot as plt 

im = plt.imread(a)

fig = plt.figure(figsize=(15,15))

plt.imshow(im)

for _ in result:
    x = [n[0] for n in _[0]]
    y = [n[1] for n in _[0]]
    plt.fill(x,y, facecolor='none', edgecolor='red')
    plt.text(x[0],y[0], _[1], color='red', fontsize=15)

plt.axis('off')
plt.savefig('output_easyocr.png')
plt.show()

# %%
# !pip install pytesseract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install tesseract
# !apt-get install tesseract-ocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2build2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
import pytesseract
from PIL import Image

# Path to the image file
image_path = a 

# Open the image file using PIL (Python Imaging Library)
image = Image.open(image_path)

# Perform OCR using Pytesseract
text = pytesseract.image_to_string(image)

# Print the extracted text
print(text)

# Save the extracted text in a text file
text_file = open('/content/drive/MyDrive/extracted_text.txt', 'w')
text_file.write(text)
text_file.close()

print('Text extracted and saved successfully!')
# Out:
# EDITORIAL
#
# vel coronavirus (2019-nC
#
#
#
# Eurosurveillance editori
#
#
#
# team
#
# 4. European Centre for Disease Prevention and Control (ECDC), Stockholm, Sweden
# Correspondence: Eurosurveillance editorial team (eurosurveillance@ecdc.europa.eu)
#
# tation style for this article:
#
# Eurosurvellance editorial team. Note from the editors: noel coronavirus (2019-nCo¥) Euro Surveill 2020%25(3}:pi=2001231 ttp|/dl.org/s0.2807/1560-79y7.
#
# ESizoa0.25.2001291
#
# At the end of 2019, on 31 December, the World Health
# Organization (WHO) Country Office in China was
# informed of cases of pneumonia of unknown aetiol-
# ogy that had been detected in Wuhan, a city in the
# province of Hubei. Just a day earlier, on 30 December,
# ProMED-mail published a post calling for more infor-
# mation about ‘A cluster of undiagnosed pneumonia -
# China (Hubei)’. The post indicated that there had been
# some 20 patients diagnosed with ‘atypical pneumo-
# ...

# %%
import spacy

# Load the SpaCy English model
nlp = spacy.load('en_core_web_sm')

# Read text from a file
filename = b  # Replace with your file path
with open(filename, 'r') as file:
    text = file.read()

# Process the text
doc = nlp(text)

# Extract named entities and group them by type
entities = {}
for ent in doc.ents:
    entity_type = ent.label_
    entity_text = ent.text
    if entity_type in entities:
        entities[entity_type].append(entity_text)
    else:
        entities[entity_type] = [entity_text]

# Print the grouped entities
for entity_type, entity_texts in entities.items():
    print(entity_type + ":")
    for entity_text in entity_texts:
        print("\t", entity_text)
# Out:
# DATE:
# 	 2019
# 	 2019-nCo¥
# 	 2020%25(3}:pi=2001231 ttp|/dl.org/s0.2807/1560-79y7
# 	 the end of 2019
# 	 31 December
# 	 Just a day earlier
# 	 30 December
# 	 2003
# 	 just a few weeks later
# 	 23 January
# 	 7 January 2020
# 	 2019
# 	 10 January
# 	 2 days later
# 	 daily
# 	 2019
# 	 2019
# 	 Today
# 	 2019
# 	 2019
# 	 23 Jan 2019
# 	 23 Jan 2020
# 	 22 Jan 2020
# CARDINAL:
# 	 4
# 	 some 20
# 	 seven
# 	 1
# 	 614
# 	 17
# 	 2
# 	 3
# 	 3
# 	 4
# 	 four
# 	 two
# 	 five
# 	 5
# 	 6
# 	 4
# 	 20191230.6864153
# 	 30
# 	 22
# 	 3
# ORG:
# 	 European Centre for Disease Prevention and Control
# 	 ECDC
# 	 the World Health
# Organization (WHO) Country Office
# 	 Eurosurveillance
# 	 RT-PCR
# 	 RdRp
# 	 nCoV
# 	 WHO
# 	 the International Health
# Regulations (IHR) Emergency Committee
# 	 nCoV
# 	 the European
# Centre for Disease Prevention and Control
# 	 ECDC
# 	 WHO
# 	 ECDC
# 	 Pro-MED
# 	 PRO/AH/EDR
# 	 Request For Information
# ...

# %%
# Save the grouped entities in a CSV file
output_file = '/content/drive/MyDrive/output_entities101.csv'  
with open(output_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Entity Type', 'Entity Text'])  # Write header row
    for entity_type, entity_texts in entities.items():
        for entity_text in entity_texts:
            writer.writerow([entity_type, entity_text])

print("Entities saved to CSV file:", output_file)
# Out:
# Entities saved to CSV file: /content/drive/MyDrive/output_entities101.csv
